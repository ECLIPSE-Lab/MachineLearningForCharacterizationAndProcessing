# %% [markdown]
# #
#
# # Week 7 Summary: No lecture — Pfingsten public holiday (26.05.2026)
#
# **Cancelled** — Week 7 (Pfingstmontag / Pfingstdienstag, 25–26.05.2026) has no lecture and no exercise. The *time-series and process monitoring* unit moved to Week 8 (02.06.2026), and every later unit shifted one week, taking up the former Week-14 buffer slot.
#
# **Summary for ML-PC Week 7:** No session — public holiday.
